# %%
pip install -U langgraph
# Out:
# Requirement already satisfied: langgraph in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (0.0.50)
# Collecting langgraph
#   Using cached langgraph-1.0.3-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchain-core>=0.1 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (0.3.63)
# Collecting langgraph-checkpoint<4.0.0,>=2.1.0 (from langgraph)
#   Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl.metadata (4.7 kB)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.2 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (1.0.2)
# Collecting langgraph-sdk<0.3.0,>=0.2.2 (from langgraph)
#   Downloading langgraph_sdk-0.2.9-py3-none-any.whl.metadata (1.5 kB)
# Requirement already satisfied: pydantic>=2.7.4 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (2.12.4)
# Requirement already satisfied: xxhash>=3.5.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph) (3.5.0)
# Collecting ormsgpack>=1.12.0 (from langgraph-checkpoint<4.0.0,>=2.1.0->langgraph)
#   Downloading ormsgpack-1.12.0-cp312-cp312-win_amd64.whl.metadata (1.2 kB)
# Collecting langchain-core>=0.1 (from langgraph)
#   Downloading langchain_core-1.1.0-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: httpx>=0.25.2 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.28.1)
# Requirement already satisfied: orjson>=3.10.1 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11.4)
# Requirement already satisfied: anyio in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (4.11.0)
# Requirement already satisfied: certifi in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (2025.11.12)
# Requirement already satisfied: httpcore==1.* in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.0.9)
# Requirement already satisfied: idna in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (3.11)
# Requirement already satisfied: h11>=0.16 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (0.16.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (1.33)
# Collecting langsmith<1.0.0,>=0.3.45 (from langchain-core>=0.1->langgraph)
#   Downloading langsmith-0.4.46-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (23.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (8.5.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langchain-core>=0.1->langgraph) (4.15.0)
# Requirement already satisfied: jsonpointer>=1.9 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core>=0.1->langgraph) (3.0.0)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.32.5)
# Requirement already satisfied: zstandard>=0.23.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.5 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (2.41.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from pydantic>=2.7.4->langgraph) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core>=0.1->langgraph) (2.3.0)
# Requirement already satisfied: sniffio>=1.1 in c:\users\janhavi\appdata\local\programs\python\python312\lib\site-packages (from anyio->httpx>=0.25.2->langgraph-sdk<0.3.0,>=0.2.2->langgraph) (1.3.1)
# Using cached langgraph-1.0.3-py3-none-any.whl (156 kB)
# Downloading langgraph_checkpoint-3.0.1-py3-none-any.whl (46 kB)
# Downloading langgraph_sdk-0.2.9-py3-none-any.whl (56 kB)
# Downloading langchain_core-1.1.0-py3-none-any.whl (473 kB)
# Downloading langsmith-0.4.46-py3-none-any.whl (411 kB)
# Downloading ormsgpack-1.12.0-cp312-cp312-win_amd64.whl (112 kB)
# Installing collected packages: ormsgpack, langsmith, langgraph-sdk, langchain-core, langgraph-checkpoint, langgraph
#
#   Attempting uninstall: ormsgpack
#
#     Found existing installation: ormsgpack 1.10.0
#
#     Uninstalling ormsgpack-1.10.0:
#
#       Successfully uninstalled ormsgpack-1.10.0
#
#   Attempting uninstall: langsmith
#
#    ------ --------------------------------- 1/6 [langsmith]
#     Found existing installation: langsmith 0.1.147
#    ------ --------------------------------- 1/6 [langsmith]
#     Uninstalling langsmith-0.1.147:
#    ------ --------------------------------- 1/6 [langsmith]
#       Successfully uninstalled langsmith-0.1.147
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------ --------------------------------- 1/6 [langsmith]
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#   Attempting uninstall: langchain-core
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#     Found existing installation: langchain-core 0.3.63
#    ------------- -------------------------- 2/6 [langgraph-sdk]
#    -------------------- ------------------- 3/6 [langchain-core]
#     Uninstalling langchain-core-0.3.63:
#    -------------------- ------------------- 3/6 [langchain-core]
#       Successfully uninstalled langchain-core-0.3.63
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------- ------------------- 3/6 [langchain-core]
#    -------------------------- ------------- 4/6 [langgraph-checkpoint]
#    -------------------------- ------------- 4/6 [langgraph-checkpoint]
#   Attempting uninstall: langgraph
#    -------------------------- ------------- 4/6 [langgraph-checkpoint]
#     Found existing installation: langgraph 0.0.50
#    -------------------------- ------------- 4/6 [langgraph-checkpoint]
#     Uninstalling langgraph-0.0.50:
#    -------------------------- ------------- 4/6 [langgraph-checkpoint]
#    --------------------------------- ------ 5/6 [langgraph]
#       Successfully uninstalled langgraph-0.0.50
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    --------------------------------- ------ 5/6 [langgraph]
#    ---------------------------------------- 6/6 [langgraph]
#
# Successfully installed langchain-core-1.1.0 langgraph-1.0.3 langgraph-checkpoint-3.0.1 langgraph-sdk-0.2.9 langsmith-0.4.46 ormsgpack-1.12.0
# Note: you may need to restart the kernel to use updated packages.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain 0.3.7 requires langchain-core<0.4.0,>=0.3.15, but you have langchain-core 1.1.0 which is incompatible.
# langchain 0.3.7 requires langsmith<0.2.0,>=0.1.17, but you have langsmith 0.4.46 which is incompatible.
# langchain-classic 1.0.0 requires langchain-text-splitters<2.0.0,>=1.0.0, but you have langchain-text-splitters 0.3.1 which is incompatible.
# langchain-community 0.3.2 requires langchain-core<0.4.0,>=0.3.10, but you have langchain-core 1.1.0 which is incompatible.
# langchain-community 0.3.2 requires langsmith<0.2.0,>=0.1.125, but you have langsmith 0.4.46 which is incompatible.
# langchain-experimental 0.4.0 requires langchain-community<1.0.0,>=0.4.0, but you have langchain-community 0.3.2 which is incompatible.
# langchain-google-genai 2.0.10 requires langchain-core<0.4.0,>=0.3.37, but you have langchain-core 1.1.0 which is incompatible.
# langchain-groq 0.3.2 requires langchain-core<1.0.0,>=0.3.49, but you have langchain-core 1.1.0 which is incompatible.
# langchain-text-splitters 0.3.1 requires langchain-core<0.4.0,>=0.3.13, but you have langchain-core 1.1.0 which is incompatible.

# %%
from langgraph.graph import StateGraph, END
from typing import TypedDict
from IPython.display import Image, display

# %%
class MyState(TypedDict):
    message: str

# Define the start node
def start_node(state: MyState) -> MyState:
    print("Start node received:", state["message"])
    # Process or pass the message to the end node
    return {"message": state["message"] + " -> processed by start"}

# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# Build the graph
builder = StateGraph(MyState)


# Define the end node
def end_node(state: MyState) -> MyState:
    print("End node received:", state["message"])
    return state

# %%
# Build the graph
builder = StateGraph(MyState)

# %%
# Add nodes
builder.add_node("start", start_node)
builder.add_node("end", end_node)

# %%
# Define the flow
builder.set_entry_point("start")
builder.add_edge("start", "end")
builder.add_edge("end", END)  # END is a special marker for graph completion

# %%
# Compile the graph
graph = builder.compile()

# Run the graph
result = graph.invoke({"message": "Hello LangGraph"})
print("Final result:", result["message"])
# Out:
# Start node received: Hello LangGraph
# End node received: Hello LangGraph -> processed by start
# Final result: Hello LangGraph -> processed by start
